# %%
#Changing plot style and color

sns.set_style("whitegrid")#ubah latar plot
'''
pilihan lainnya:
1.ticks
2.dark
3.darkgrid
'''
sns.set_pallete('RdBu') #ubah warna plot

sns.sec_context("talk")#ubah ukuran plot
'''
pilihan lainnya:
1.paper
2.notebook
3.poster
'''

sns.catplot(x = "age", y = "masculinity_important", data = masculinity_data, kind = "point", hue = "feel_masculine")
plt.show()

# %%
#Latihan 1
# Change the color palette to "RdBu"
sns.set_style("whitegrid")
sns.set_palette("RdBu")

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents Advice", 
            data=survey_data, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %%
#Latihan 2
# Change the context to "poster"
sns.set_context("poster")

# Create bar plot
sns.catplot(x="Number of Siblings", y="Feels Lonely",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
#Latihan 3
# Set the style to "darkgrid"
sns.set_style("darkgrid")

# Set a custom color palette
sns.set_palette(["#39A7D0", "#36ADA4"])

# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age", 
            data=survey_data, kind="box")

# Show plot
plt.show()

# %%
#Adding titles and labels: Part 1
g = sns.catplot(x = "Region", y = "Birthrate", data = gdp_data, kind = "box" )
g.fig.suptitle("New title", y = 1.03) #nambah judul
plt.show()

# %%
#Latihan 1
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Show plot
plt.show()

# %%
#Adding titles and labels: Part 2


#add titles for subplot(yg bukan rel/catplot)
g = sns.boxplot(x = "Region", y = "Birthrate", data = gdp_data, col = "group")
g.fig.suptitle("New title", y = 1.03) #nambah judul
g.set_title("This is {col_name}")
plt.show()

#setting x label y label
g.set(xlabel = "ini x label", ylabel = "ini y label")

#nge rotate x axis
plt.xticks(rotation = 90)

# %%
#Latihan 1
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Add x-axis and y-axis labels
g.set(xlabel = "Car Model Year", ylabel = "Average MPG")


# Show plot
plt.show()

# %%
#Latihan 2
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation = 90)

# Show plot
plt.show()

# %%
#Putting it all together
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Latihan 1
# Set palette to "Blues"
sns.set_palette("Blues")

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_data, 
                kind="box", hue= "Interested in Pets")

# Set title to "Age of Those Interested in Pets vs. Not"
g.fig.suptitle('Age of Those Interested in Pets vs. Not')

# Show plot
plt.show()

# %%
#Latihan 2
# Set the figure style to "dark"
sns.set_style("dark")

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Likes Techno", 
                data=survey_data, kind="bar",
                col = "Gender")

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence", 
       ylabel="% Who Like Techno")

# Show plot
plt.show()
